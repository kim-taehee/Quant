# %%
import numpy as np

# %%
y =  np.random.standard_normal((20,2)).cumsum(axis=0)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(7,4))
plt.plot(y, lw=1.5)
plt.plot(y,'ro')
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A sample plot')
# Out:
# Text(0.5,1,'A sample plot')

# %%
plt.figure(figsize=(7,4))
plt.plot(y[:,0],lw=1.5, label='1st')
plt.plot(y[:,1],lw=1.5 ,label='2nd')
plt.plot(y,'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A sample plot')
# Out:
# Text(0.5,1,'A sample plot')

# %%
y[:,1]=y[:,0]*100
plt.figure(figsize=(7,4))
plt.plot(y[:,0],lw=1.5, label='1st')
plt.plot(y[:,1],lw=1.5 ,label='2nd')
plt.plot(y,'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A sample plot')
# Out:
# Text(0.5,1,'A sample plot')

# %% [markdown]
# ##  y축 두개를 만들기

# %%
y =  np.random.standard_normal((20,2)).cumsum(axis=0)

# %%
fig, ax1 = plt.subplots()
plt.plot(y[:,0], 'b', lw=1.5, label= '1st')
plt.plot(y[:,0], 'rp')
plt.grid(True)
plt.legend(loc=8)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value 1st')
plt.title('A sample plot')
ax2 =ax1.twinx()
plt.plot(y[:,1], 'g', lw=1.5, label= '2nd')
plt.plot(y[:,1], 'go')
plt.legend(loc=0)
plt.ylabel('value 2nd')
# Out:
# Text(0,0.5,'value 2nd')

# %%
plt.Figure(figsize=(7,5))
plt.subplot(211)
plt.plot(y[:,0], lw=1.5 , label='1st')
plt.plot(y[:,0],"ro")
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
plt.title('A sample plt')
plt.subplot(212)
plt.plot(y[:,0], lw=1.5 , label='1st')
plt.plot(y[:,0],"ro")
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
plt.title('A sample plt')
# Out:
# Text(0,0.5,'value')

# %%
plt.figure(figsize=(9,4))
plt.subplot(121)
plt.plot(y[:,0], lw=1.5 , label='1st')
plt.plot(y[:,0],"ro")
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
plt.title('1st plt')
plt.subplot(122)
plt.bar(np.arange(len(y)),y[:,1],width=0.5, color='g',label='2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
plt.title('the 2nd plt')
# Out:
# Text(0.5,1,'the 2nd plt')

# %%
y=np.random.standard_normal((1000,2))
c=np.random.randint(0,10,len(y))
plt.figure(figsize=(7,5))
plt.scatter(y[:,0],y[:,1],c=c,marker='o')
plt.colorbar()
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('scatter plot')
# Out:
# Text(0.5,1,'scatter plot')

# %%
plt.Figure(figsize=(7,4))
plt.hist(y,label=['1st','2nd'],bins=25)
plt.grid(True)
plt.xlabel('value')
plt.ylabel('Frequancy')
plt.title('Histogram')
# Out:
# Text(0.5,1,'Histogram')

# %%
strike = np.linspace(50,150,24) # 행사가는 50에서 150 사이
ttm = np.linspace(0.5,2.5,24)  # 만기는 0.5년에서 2.5 사이 24 Slice
strike, ttm= np. meshgrid(strike,ttm)

# %%
iv = (strike -100 ) ** 2 /(100 * strike) /ttm

# %%
# from mpl_toolkits.mplot3d import Axes3d
# 중략
